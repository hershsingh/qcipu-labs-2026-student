# %% [markdown]
# # 1 Qubit Gates: Visualizing with IBM Composer
#
# ## Objectives:
# * Get familiar with IBM Composer
# * Create a Bell State
# * Learn how to visualize states
# * Learn about 1-qubit quantum gates
#
# Adopted from https://quantum-computing.ibm.com/composer/docs/iqx/first-circuit and https://quantum-computing.ibm.com/composer/docs/iqx/visualizations#phase-disk
#
# To start, <b>go to IBM Q</b> and instead of opening IBM Quantum Lab, <b>open the IBM Composer</b> (https://quantum.ibm.com/composer/files/new).  You should be greated by a page that looks something like:
#
# ![Screenshot from 2024-05-24 11-15-12.png](data:image/png;base64,...)

# %% [markdown]
# *To* get oriented, first I would direct you attention to the upper left corner of the composer:
#
# ![Screenshot from 2024-06-17 15-41-13.png](data:image/png;base64,...)
#
# Here, you should see the name of your quantum circuit, currently "Untitled circuit".  <b>Click on this text and change it to something you can remember</b>, perhaps "Hanks_wicked_first_go".
#
# Directly below this, you should see a bunch of colorful buttons.  These are the various quantum gates you are allowed to use.
# * <b>Right click on the two X's connected by a line (first row started with red H, fifth element) and then click on "Info". In the cell below, write what the name of this gate is.</b>
# * <b>Also click on the P gates, and gate with a speedometer pointing at a z, what do these correspond to?</b>

# %%
#=================================================

#Replace the ???? with your answer here

print("x-x (But from top to bottom) is called: ????")

print("P is called: ????")

print("Speedometer pointing at a z is called:????")

#================================================
# Out:
# x-x (But from top to bottom) is called: ????
# P is called: ????
# Speedometer pointing at a z is called:????

# %% [markdown]
# Directly to the right of the gates is the circuit, where you will be able to drag individual gates onto to build something magical. The reason this setup is called a "composer" is that each qubit can be thought of as a string, and the gates acting on them are the particular notes you want to play.  Importantly, you can only play one "note" per timestep on each string, so you have to consider how your time ordering effects your results.  This is all a consequence of the gates not being <b>commutatitve</b>
#
# ![qubits.png](attachment:qubits.png)
#
# This setup should look familiar to Josh's lectures. The "q" label each of your qubits, and the "c" label the classical bits that can be used for storing the results of measurements.
#
# * <b>Click the on "q3" and then on the (+). What happens to your circuit?</b>
#
# * After clicking on "q4", you should see a trashbin. <b>Click the trashbin, and you will see that the given qubit was removed.</b> Do the same to "q3".
#
# * Now we are left with three qubits and four classical bits. <b>Click on the classical bits and then on (-), this removes one of the classical bits.</b> Now we are left with 3 qubits and 3 classical bits.
#
# * If you <b>hover over the "phase disks"</b> <i>(I think they look like clocks)</i> on the far right, you will see the state of that specific qubit.

# %% [markdown]
# ## Probabilities
#
# Below the circuit, on the left you will see a bar graph called <b>Probabilities</b>
#
# ![Screenshot%20from%202021-07-13%2009-17-56%20%28another%20copy%29.png](attachment:Screenshot%20from%202021-07-13%2009-17-56%20%28another%20copy%29.png)
# ![Screenshot from 2024-05-24 11-16-55.png](data:image/png;base64,...)
# As you change your circuit, this plot will adjust to show you the outcome of performing a measurement in the Z-basis on the final state of your circuit.  In a further tragedy of notation, the qubits from top to bottom are labelled right to left
#
# * <b>Put down a Hadamard gate, H, on qubit q0.  Does the Probabilities plot show what you expected? </b>
#
# ## q-sphere
#
# To the right of the Probabilities chart, is the <i>q-sphere</i>.
#
# ![Screenshot%20from%202021-07-13%2009-17-56%20%28copy%29.png](attachment:Screenshot%20from%202021-07-13%2009-17-56%20%28copy%29.png)
# ![Screenshot from 2024-05-24 11-17-19.png](data:image/png;base64,...)
# The q-sphere represents the state of a system of one or more qubits by associating each computational basis state with a point on the surface of a sphere. A node is visible at each point. Each node’s radius is proportional to the probability $p_k$ of its basis state, whereas the node color indicates the quantum phase $\varphi_k$.
#
# The nodes are laid out on the q-sphere so that the basis state with all zeros (e.g., $|000\rangle$) is at its north pole, and the basis state with all ones (e.g., $|111\rangle$) is at its south pole. Basis states with the same number of zeros (or ones) lie on a shared latitude of the q-sphere (e.g., $|001\rangle, |101\rangle$).
#
# Beginning at the north pole of the q-sphere and progressing southward, each successive latitude has basis states with a greater number of ones; the latitude of a basis state is determined by its distance from the zero state. The q-sphere contains complete information about the quantum state in a compact representation.
#
# <b>You can select, hold, and drag to rotate the q-sphere. To return the q-sphere to its default orientation, select the rewind-arrow button to the top right of the q-sphere.</b>
#
# At this point, you have certainly asked yourself, Hank...isn't this just the Bloch sphere for multiple qubits?  Well IBM would very much like you to know it isn't
#
# ### <b>What is the difference between a Bloch sphere and a q-sphere?</b>
#
# The q-sphere is not the Bloch sphere, even for a single qubit. Indeed, like the phase disk, the Bloch sphere gives a local view of the quantum state, where each qubit is viewed on its own. When trying to understand how multi-qubit states behave upon the application of quantum circuits, it is more insightful to take a global view. The q-sphere provides a visual representation of the quantum state.
#
# * <b>Try having one Hadamard gate onto each of the 3 qubits in your circuit</b> How does your q-sphere change?

# %% [markdown]
# ## Python Code
#
# The final important part of the IBM Composer is the Python IDE on the right hand side.
# Delete all gates that you placed in the previous step and you should see something like in the following picture.
#
# ![Screenshot%20from%202021-07-13%2009-17-56%20%285th%20copy%29.png](attachment:Screenshot%20from%202021-07-13%2009-17-56%20%285th%20copy%29.png)
# ![Screenshot from 2024-05-24 11-18-19.png](data:image/png;base64,...)
#
# Here, the circuit that you manipulating is displayed in one of two ways for quantum computing: OpenQASM (a programming language) or QISKIT (a python module).
#
# * <b> Put a T gate on qubit q0, and a Hadamard gate on qubit q1.</b> Notice how the OpenQASM code changes.
# * <b> Using the results of previous step as a guide, can you code in OpenQASM that q2 should be acted on by a T gate followed by an H gate?</b>  Did you circuit change in the way you expected?
#
# As a check of your results, do your probabilities match the chart below?
#
# ![Screenshot from 2024-05-24 11-19-55.png](data:image/png;base64,...)

# %% [markdown]
# # Bell States and QISKIT
#
# While OpenQASM is a perfectly good langauge, in the interest of consistence and ease we will be using QISKIT for most of the rest of school.  This allows us access to all the nice features of python, but does make the code a bit dirtier than OpenQASM. Unfortunately, QISKIT code isn't directly editable in IBM Composer.
#
# *To begin, <b>click where "OpenQASM" appears, and from the dropdown menu select QISKIT</b>. The code should change into the QISKIT equivalent of the circuit.
#
# *Clear all the gates from your circuit.
#
# At this point, the QISKIT code should appear like:
#
# ![Screenshot from 2024-05-24 11-21-34.png](data:image/png;base64,...)![qiskit_code.png](attachment:qiskit_code.png)
#
# The first lines import the necessary modules, like any good python. The next set of lines sets up your circuit:
#
#     qreg_q = QuantumRegister(3, 'q')
#
# Defines a variable "qreg_q" which will be a quantum register with 3 qubits accessable through the list qreg_q[] and with the labels "q".
#
# * Can you interpret what the next two lines do?
# They are:
#
#     creg_c = ClassicalRegister(3, 'c')
#
#     circuit = QuantumCircuit(qreg_q, creg_c)

# %% [markdown]
# =============================================
#
# Answers here:
#
#     creg_c = ClassicalRegister(3, 'c') : ???????
#
#     circuit = QuantumCircuit(qreg_q, creg_c) : ???????
#
# =============================================

# %% [markdown]
# As we go through the next exercises, <b>keep an eye on the QISKIT code</b>
#
# If you have ever done programming before, you may have heard of a "Hello World" program, which is jargon for a simple program to introduce you to langauge.  Preparing and measuring a Bell state is what is often called the "Hello World" of quantum computing.
#
# What is a Bell State?  Well its a state we have been talking about almost all school:
#
#    $\LARGE|Bell\rangle=\frac{|00\rangle+|11\rangle}{\sqrt{2}}$
#
# To prepare this 2-qubit state, you could proceed in two steps:
#
# * First, prepare one of your qubits in the $\frac{|0\rangle+|1\rangle}{\sqrt{2}}$. To do this, you need to perform a Hadamard gate on this qubit.
#
# * Next, you need to entangle two of your qubits through a two-qubit or "entangling gate".  In this case, a controlled-NOT gate: CNOT.
#
# When you have a controlled gate, it means that some qubits will be manipulated contingent upon the state of other ones.  For the CNOT on the composer, this is done by representing the <b>controlled</b> qubit by a (+) symbol, while the <b>controller</b> qubit is given by a (.)
#
# * To prepare the Bell state, the qubit that was placed in the Hadamard state should be the controller.
#
# You should now have a Bell state prepared.  <b>Do your Probablities and q-sphere correspond to your expectations?</b>
#
# * Now, perform a measurement on each of the qubits.  You should see each gate snap to a connection to the classical qubits.
#
# <b>How have the probabilities changed by including the measurements?</b>
#
# You should see that we have "collapsed the wavefunction" by the measurement.  If you want to perform the quantum circuit again, but with a potentially different result, <b>change the number beside the "Visualization Seed".</b>
#
# *By <b>changing the seed many times</b>, do you eventually see all the outcomes you expected?
#
# At this point, your QISKIT code should look like:
#
# ![Screenshot from 2024-05-24 11-23-30.png](data:image/png;base64,...)
#
# Can you recognize how each line of code corresponds to your circuit?
#
# ## Inspect
#
# One final interesting feature of the Composer is "Inspect".  This feature is akin to the classical debugging feature where you are allowed to step through the function and see what condition the computer is in at any state. <i> In general, this is not possible for quantum computers because...measuring the state "collapses the wavefunction."</i> But since we are presently using a classical simulator of a small number of qubits, we can keep track of the full quantum state.
#
# * Try stepping through your code and seeing how things work.
